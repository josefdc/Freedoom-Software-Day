# %%
var('u v')
x = (4 + (2 + cos(v)) * cos(u)) * cos(2 * v)
y = (4 + (2 + cos(v)) * cos(u)) * sin(2 * v)
z = (2 + cos(v)) * sin(u) + 2 * sin(v)
Klein = parametric_plot3d([x, y, z], (u, 0, 2 * pi), (v, 0, 2 * pi), frame=False, color="blue", mesh=True)
Klein.show()
# Out:
# Graphics3d Object
